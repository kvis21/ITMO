# %%
import latexify
from sympy import pprint
@latexify.expression
def my_function(x):
    return x**3 - 3*x**2 + 7*x - 10

print(my_function) # Выведет LaTeX-код функции,
# Out:
# x^{3} - 3 x^{2} + 7 x - 10

# %%
f = lambda x: x**3-3*x**2+7*x-10
(4-2)*((41/840)*(f(2)+f(4))+(216/840)*(f(7/3)+f(11/3))+(27/840)*(f(8/3)+f(10/3))+(272/840)*f(3))
# Out:
# 25.999999999999996

# %%
a = {1: 2, 3:4}
a.items(), a.values(), a.keys()
# Out:
# (dict_items([(1, 2), (3, 4)]), dict_values([2, 4]), dict_keys([1, 3]))
